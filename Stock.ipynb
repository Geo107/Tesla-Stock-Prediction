# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ts = pd.read_csv('TSLA.csv',index_col=0)
ts
# Out:
#                    Open         High         Low        Close    Adj Close  \
# Date
# 2010-06-29     3.800000     5.000000    3.508000     4.778000     4.778000
# 2010-06-30     5.158000     6.084000    4.660000     4.766000     4.766000
# 2010-07-01     5.000000     5.184000    4.054000     4.392000     4.392000
# 2010-07-02     4.600000     4.620000    3.742000     3.840000     3.840000
# 2010-07-06     4.000000     4.000000    3.166000     3.222000     3.222000
# ...                 ...          ...         ...          ...          ...
# 2022-03-18   874.489990   907.849976  867.390015   905.390015   905.390015
# 2022-03-21   914.979980   942.849976  907.090027   921.159973   921.159973
# 2022-03-22   930.000000   997.859985  921.750000   993.979980   993.979980
# 2022-03-23   979.940002  1040.699951  976.400024   999.109985   999.109985
# 2022-03-24  1009.729980  1024.489990  988.799988  1013.919983  1013.919983
#
#               Volume
# Date
# 2010-06-29  93831500
# ...

# %%
ts['MA10'] = ts['Close'].rolling(10).mean()
ts['MA50'] = ts['Close'].rolling(50).mean()
ts = ts.dropna()

# %%
ts['Shares'] = [1 if ts.loc[ei, 'MA10']>ts.loc[ei, 'MA50'] else 0 for ei in ts.index]
# Out:
# /var/folders/zq/4k85lvtd3t77grd0m0lpxjdm0000gn/T/ipykernel_24074/3762057073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts['Shares'] = [1 if ts.loc[ei, 'MA10']>ts.loc[ei, 'MA50'] else 0 for ei in ts.index]

# %%
ts.head
# Out:
# <bound method NDFrame.head of                    Open         High         Low        Close    Adj Close  \
# Date
# 2010-09-08     4.132000     4.190000    4.120000     4.180000     4.180000
# 2010-09-09     4.200000     4.210000    4.138000     4.142000     4.142000
# 2010-09-10     4.150000     4.186000    3.952000     4.034000     4.034000
# 2010-09-13     4.178000     4.180000    4.100000     4.144000     4.144000
# 2010-09-14     4.108000     4.320000    4.106000     4.224000     4.224000
# ...                 ...          ...         ...          ...          ...
# 2022-03-18   874.489990   907.849976  867.390015   905.390015   905.390015
# 2022-03-21   914.979980   942.849976  907.090027   921.159973   921.159973
# 2022-03-22   930.000000   997.859985  921.750000   993.979980   993.979980
# 2022-03-23   979.940002  1040.699951  976.400024   999.109985   999.109985
# 2022-03-24  1009.729980  1024.489990  988.799988  1013.919983  1013.919983
#
# ...

# %%
ts['Close1'] = ts['Close'].shift(-1)
ts
# Out:
# /var/folders/zq/4k85lvtd3t77grd0m0lpxjdm0000gn/T/ipykernel_24074/158472532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts['Close1'] = ts['Close'].shift(-1)
#                    Open         High         Low        Close    Adj Close  \
# Date
# 2010-09-08     4.132000     4.190000    4.120000     4.180000     4.180000
# 2010-09-09     4.200000     4.210000    4.138000     4.142000     4.142000
# 2010-09-10     4.150000     4.186000    3.952000     4.034000     4.034000
# 2010-09-13     4.178000     4.180000    4.100000     4.144000     4.144000
# 2010-09-14     4.108000     4.320000    4.106000     4.224000     4.224000
# ...                 ...          ...         ...          ...          ...
# ...

# %%
ts['Profit'] = [ts.loc[ei, 'Close1'] - ts.loc[ei, 'Close'] if ts.loc[ei, 'Shares']==1 else 0 for ei in ts.index]

ts
# Out:
# /var/folders/zq/4k85lvtd3t77grd0m0lpxjdm0000gn/T/ipykernel_24074/3297452892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts['Profit'] = [ts.loc[ei, 'Close1'] - ts.loc[ei, 'Close'] if ts.loc[ei, 'Shares']==1 else 0 for ei in ts.index]
#                    Open         High         Low        Close    Adj Close  \
# Date
# 2010-09-08     4.132000     4.190000    4.120000     4.180000     4.180000
# 2010-09-09     4.200000     4.210000    4.138000     4.142000     4.142000
# 2010-09-10     4.150000     4.186000    3.952000     4.034000     4.034000
# 2010-09-13     4.178000     4.180000    4.100000     4.144000     4.144000
# 2010-09-14     4.108000     4.320000    4.106000     4.224000     4.224000
# ...

# %%
ts['Profit'].plot()
plt.axhline(y=0, color='red')

# %%
ts['wealth'] = ts['Profit'].cumsum()
ts.tail()
# Out:
# /var/folders/zq/4k85lvtd3t77grd0m0lpxjdm0000gn/T/ipykernel_24074/1734672343.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts['wealth'] = ts['Profit'].cumsum()
#                    Open         High         Low        Close    Adj Close  \
# Date
# 2022-03-18   874.489990   907.849976  867.390015   905.390015   905.390015
# 2022-03-21   914.979980   942.849976  907.090027   921.159973   921.159973
# 2022-03-22   930.000000   997.859985  921.750000   993.979980   993.979980
# 2022-03-23   979.940002  1040.699951  976.400024   999.109985   999.109985
# 2022-03-24  1009.729980  1024.489990  988.799988  1013.919983  1013.919983
#
#               Volume        MA10        MA50  Shares       Close1  Profit  \
# Date
# ...

# %%
ts['wealth'].plot()
plt.title('Total money you win is {}'.format(ts.loc[ts.index[-2], 'wealth']))
# Out:
# Text(0.5, 1.0, 'Total money you win is 623.041958')
